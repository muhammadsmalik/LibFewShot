# %%
# !git clone https://github.com/RL-VIG/LibFewShot.git
# Out:
# Cloning into 'LibFewShot'...
# remote: Enumerating objects: 4746, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 4746 (delta 59), reused 90 (delta 42), pack-reused 4614
# Receiving objects: 100% (4746/4746), 5.03 MiB | 1.28 MiB/s, done.
# Resolving deltas: 100% (3348/3348), done.

# %%
# !pip install -r LibFewShot/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 878.2 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 kB 1.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 2.7 MB/s eta 0:00:0000:0100:01m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.9/28.9 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 1.6 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.5/242.5 kB 2.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 534.1 kB/s eta 0:00:00a 0:00:01
# ...

# %%
# !python run_trainer.py

# 8 min 42 secs
# Out:
# [05/24/23 23:48:40] INFO     the model will be performed on CPU.  ]8;id=926816;file:///Users/salmanmalik/Documents/MPhil/LibFewShot/core/trainer.py\trainer.py]8;;\:]8;id=752923;file:///Users/salmanmalik/Documents/MPhil/LibFewShot/core/trainer.py#372\372]8;;\
#                     INFO     {'data_root':                        ]8;id=202737;file:///Users/salmanmalik/Documents/MPhil/LibFewShot/core/trainer.py\trainer.py]8;;\:]8;id=161221;file:///Users/salmanmalik/Documents/MPhil/LibFewShot/core/trainer.py#372\372]8;;\
#                              'data/consolidated_seeds_dataset',
#                              'image_size': 84, 'use_memory':
#                              False, 'augment': True,
#                              'augment_times': 1,
#                              'augment_times_query': 1, 'workers':
#                              2, 'dataloader_num': 1,
#                              'device_ids': 0, 'n_gpu': 1, 'seed':
# ...

# %%
# !tensorboard --logdir=/Users/salmanmalik/Documents/MPhil/LibFewShot/results/ProtoNet-consolidated_seeds_dataset-Conv64F-2-1-May-24-2023-23-48-40
# Out:
# TensorFlow installation not found - running with reduced feature set.
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.13.0 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
# !pip install tensorflow
